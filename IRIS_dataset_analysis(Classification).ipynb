# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
# Import the pandas library and alias it as pd
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("/content/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Drop the column named "Id" (with a capital I)
# First, check the column names to ensure 'Id' exists and is spelled correctly
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Import the pandas library and alias it as pd
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("/content/Iris.csv")

df.head()

# Drop the column named "Id" (with a capital I)
# First, check the column names to ensure 'Id' exists and is spelled correctly
print(df.columns)

# Then, attempt to drop the column
# Based on the KeyError, the column 'Id' with this capitalization
# was not found. Let's assume the column name in the CSV
# is actually 'Id' as is common for this dataset.
# The print(df.columns) output would confirm the exact name.
# If the printed column name is different, e.g., 'id',
# change the string in the list below to match it.
df = df.drop(columns= ["Id"])
df.head()
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df["Species"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object>

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df["SepalLengthCm"].hist()
# Out:
# <Axes: >

# %%
df["SepalWidthCm"].hist()
# Out:
# <Axes: >

# %%
df["PetalWidthCm"].hist()
# Out:
# <Axes: >

# %%
colors = ["orange" , "blue" , "yellow"]
Species = ["Iris versicolor" , "Iris virginica" , "Iris setosa"]

# %%
print(df.head())
print(df["Species"].unique())
Species = df["Species"].unique()  # Ensure this is defined
colors = ['red', 'green', 'blue']  # Or any other color list
len(Species) == len(colors) >= 3
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# True

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data (use correct path or dataset)
df = pd.read_csv("Iris.csv")  # Adjust path if needed

# Check data
print(df.head())
print(df["Species"].unique())

Species = df["Species"].unique()
colors = ['red', 'green', 'blue']

for i in range(len(Species)):
    x = df[df["Species"] == Species[i]]
    plt.scatter(x["SepalLengthCm"], x["SepalWidthCm"], c=colors[i], label=Species[i])

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Sepal Length vs Sepal Width by Species")
plt.legend()
plt.show()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
for i in range(3):
    x=df[df['Species'] == Species[i]]
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = colors[i], label = Species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    # This is the outer loop. The code inside this loop should be indented.
    for i in range(3):
        # This is the inner loop. The code inside this loop should be indented relative to the inner for loop.
        x=df[df['Species'] == Species[i]]
        plt.scatter(x['PetalLengthCm'], x['SepalLengthCm'], c = colors[i], label = Species[i])
    # The following lines seem to be intended to be outside the inner loop,
    # possibly after the plots for a single species are done, or after all species are plotted.
    # Assuming they are meant to be after the inner loop completes for a given outer loop iteration.
    # If you only want one set of labels and legend at the end, move these lines outside both loops.
plt.xlabel("Sepal Length") # Note: The scatter plot uses PetalLength and SepalLength, but the label says Sepal Length. This might be a logical error.
plt.ylabel("Sepal Width") # Note: The scatter plot uses PetalLength and SepalLength, but the label says Sepal Width. This might be a logical error.
plt.legend() # Fix the incomplete plt.legend( call

# If you only want one plot with one legend and one set of labels at the very end,
# the last three lines should be moved completely outside both loops.
# Example if you want labels/legend after all data points are plotted:
# for i in range(3):
#     for i in range(3):
#         x=df[df['Species'] == Species[i]]
#         plt.scatter(x['PetalLengthCm'], x['SepalLengthCm'], c = colors[i], label = Species[i])
#
# plt.xlabel("Petal Length (cm)") # Correcting based on scatter plot axes
# plt.ylabel("Sepal Length (cm)") # Correcting based on scatter plot axes
# plt.legend()

# %%
for i in range(3):
    x=df[df['Species'] == Species[i]]
    plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], c = colors[i], label = Species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=np.number)

# Calculate and display the correlation matrix for the numeric columns
numeric_df.corr()

# Alternatively, you can drop the 'Species' column before calculating correlation
# df_numeric_only = df.drop(columns=['Species'])
# df_numeric_only.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is already loaded and processed as in the previous cells
# For example:
# df = pd.read_csv("/content/Iris.csv")
# df = df.drop(columns=["Id"])


# Select only numeric columns for correlation calculation
# This excludes the 'Species' column which contains strings
numeric_df = df.select_dtypes(include=np.number)

# Calculate the correlation matrix for the numeric columns
corr = numeric_df.corr()

# Create the heatmap
fig, ax = plt.subplots(figsize=(3,4))
sns.heatmap(corr, annot=True, ax=ax , cmap="coolwarm")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df["Species"] = le.fit_transform(df["Species"])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Species"])
y = df["Species"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy:" , model.score(x_test , y_test) *100)
# Out:
# Accuracy: 100.0

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train , y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:" , model.score(x_test , y_test) *100)
# Out:
# Accuracy: 100.0

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# Fit the model using the training data (x_train and y_train)
model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:" , model.score(x_test , y_test) *100)
# Out:
# Accuracy: 96.66666666666667
